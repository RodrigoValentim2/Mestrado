# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv("contagem_01.csv", sep="\t")

# %%
df.head()
# Out:
#    Nº do par  Humano  Máquina  Humano.1  Máquina.1
# 0         54     131      334       155        113
# 1         55     208      751        89        254
# 2         56      14       27         2          5
# 3         57     127      229       199        329
# 4         58     203      597       297        760

# %%
palhetas = np.array(df['Nº do par'], dtype=str)
plt.figure(figsize=(8,5))
plt.plot(palhetas, df['Humano'],  color='blue', marker=1, label='Humano')
plt.plot(palhetas, df['Máquina'],  color='red', marker="o", label="Máquina");
plt.title("Grupo de palhetas 1")
plt.xlabel("Número do par", fontsize=15)
plt.ylabel("Número de ovos",fontsize=15 )
plt.ylim(0,max(df['Humano']), 10 )
plt.legend(loc='best');
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(palhetas, df['Humano.1'],  color='blue', marker=1, label='Humano')
plt.plot(palhetas, df['Máquina.1'],  color='red', marker="o", label="Máquina");
plt.title("Grupo de palhetas 2")
plt.xlabel("Número do par", fontsize=15)
plt.ylabel("Número de ovos",fontsize=15 )
plt.ylim(0,max(df['Humano.1']), 10 )
plt.legend(loc='best');

# %% [markdown]
# # Experimento com a segunda Rede

# %%
df = pd.read_csv("contagem_02.csv")

# %%
df
# Out:
#     Nº do par  Humano  Máquina  Humano.1  Máquina.1
# 0          54     131      419       155        157
# 1          55     208      833        89        317
# 2          56      14       34         2          8
# 3          57     127      284       199        410
# 4          58     203      786       297       1027
# 5          59     131      226       117        179
# 6          60      76       50        69         37
# 7          62     109      142        88        109
# 8          63       3       28        78        106
# 9          64    1085      900      1027        763
# 10         65      86       46       114        132
# 11         66      35       74        26         60
# 12         67       4       24        47         62
# 13         68     634      452       519        361
# 14         69     110      112       211         11
# 15         70       4       11         3         39
# 16         72      38       20        53       1006
# ...

# %%
palhetas = np.array(df['Nº do par'], dtype=str)
plt.figure(figsize=(8,5))
plt.plot(palhetas, df['Humano'],  color='blue', marker=1, label='Humano')
plt.plot(palhetas, df['Máquina'],  color='red', marker="o", label="Máquina");
plt.title("Grupo de palhetas 1")
plt.xlabel("Número do par", fontsize=15)
plt.ylabel("Número de ovos",fontsize=15 )
plt.ylim(0,max(df['Humano']), 10 )
plt.legend(loc='best');
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(palhetas, df['Humano.1'],  color='blue', marker=1, label='Humano')
plt.plot(palhetas, df['Máquina.1'],  color='red', marker="o", label="Máquina");
plt.title("Grupo de palhetas 2")
plt.xlabel("Número do par", fontsize=15)
plt.ylabel("Número de ovos",fontsize=15 )
plt.ylim(0,max(df['Humano.1'])+20, 10 )
plt.legend(loc='best');
